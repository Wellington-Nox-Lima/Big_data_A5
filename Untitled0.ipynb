# %% [markdown]
# <a href="https://colab.research.google.com/github/Wellington-Nox-Lima/Big_data_A5/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# URL do arquivo CSV com dados do IBGE no GitHub
url = "https://raw.githubusercontent.com/Professor-Leonardo/temperatura/main/DataCidadeEstadoTemperatura.csv"
# Carregar os dados em um DataFrame
df = pd.read_csv(url, sep=';', encoding='ISO-8859-1')
# Exibir as linhas do DataFrame usando display
df.head()

### CONTINUE E ATUALIZE O Código Python e CRIE OS GRAFICOS PARA ESSE DataSet com dados do IBGE no GitHub

### FAÇA UPLOAD (das atividades) NA PASTA DO TEAMS [Entrega-Aula05]
# Out:
#          Data          Cidade Estado Temperatura
# 0  01/01/2023        Campinas     SP        30,2
# 1  02/01/2023        Campinas     SP        30,5
# 2  03/01/2023        Campinas     SP        29,9
# 3  01/01/2023  Ribeirao Preto     SP        32,8
# 4  02/01/2023  Ribeirao Preto     SP        33,2
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('Data').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Cidade').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Temperatura').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Cidade'].value_counts()
#     for x_label, grp in _df_3.groupby('Data')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Data')
# _ = plt.ylabel('Cidade')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Temperatura'].value_counts()
#     for x_label, grp in _df_4.groupby('Cidade')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Cidade')
# _ = plt.ylabel('Temperatura')
